# %% [markdown]
#  Analysis on Excel file.
#
#
# # Objective
#
# You have to find 20 interesting observations from this data and visualize the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('IDZ Digital data analyst.xlsx')
data.head()
# Out:
#   First Name  Last  Name  Gender   Age       Occupation   Salary  \
# 0      Jacob    Robinson    Male    58            Lawer     6779
# 1      Grace      Taylor  Female    36          Insurer     4466
# 2    Charlie      Wilson    Male    58  Aeroplane Pilot     5786
# 3    Vanessa     Farrell  Female    23            Lawer     3403
# 4     Fenton    Harrison    Male    21        Architect      693
#
#    Marital Status   No. of Children
# 0         Married                 2
# 1         Married                 1
# 2          Single                 0
# 3         Married                 2
# 4         Married                 0

# %%
data.columns = data.columns.str.replace(' ', '')

# %%
data.head()
# Out:
#   FirstName  LastName  Gender  Age       Occupation  Salary MaritalStatus  \
# 0     Jacob  Robinson    Male   58            Lawer    6779       Married
# 1     Grace    Taylor  Female   36          Insurer    4466       Married
# 2   Charlie    Wilson    Male   58  Aeroplane Pilot    5786        Single
# 3   Vanessa   Farrell  Female   23            Lawer    3403       Married
# 4    Fenton  Harrison    Male   21        Architect     693       Married
#
#    No.ofChildren
# 0              2
# 1              1
# 2              0
# 3              2
# 4              0

# %%
### Use seaborn pairplot to identify the relationship between each columns

sns.pairplot(data,height=7)

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Gender Distribution in Dataset", size=20)
sns.countplot(x=data.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### Total number of Male are more in the data as compared to Female.

# %%
plt.figure(figsize=(10,5))
plt.suptitle("Total Number of Married and Unmarried peoples in dataset", size=20)
sns.countplot(x=data.MaritalStatus)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# ## Total number of Single peoples are more in the data as compared to married peoples.
#
# So the dataset is more focused singles as compared to Married

# %%
plt.figure(figsize=(20,15))
plt.suptitle("Occupation distribution in dataset ", size=20)
sns.countplot(y=data.Occupation)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Occupation'>

# %% [markdown]
# ## As compare to other occupation
#
# ### Highest Occupations are
#   * Insurance field
#   * Biochemist field
#
# ### Lowest Occupation
#
#    * Scientist

# %%
data.groupby('Occupation').mean().sort_values('Salary',ascending=True).head(10)['Salary']
# Out:
# Occupation
# Photographer     3581.533333
# Cook             3706.000000
# Florist          3832.529412
# Jeweller         4022.764706
# Manager          4435.214286
# Programmer       4519.625000
# Botanist         4559.130435
# Actor            4631.375000
# Astronomer       4632.944444
# Mathematician    4674.833333
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(20,15))
plt.barh(data['Occupation'],data['Salary'].sort_values())
plt.show()

# %% [markdown]
# ## As compare to Occupation with Salary
#
# ### Highest Salary
#
#   * Programmer
#   * Insurance
#   * Firefighter
#   * Social Worker
#   * Historian
#
# ### Lowest Salary
#
#    * Medic
#    * Composer
#    * Graphic Designer
#    * Actor
#    * Electrician

# %%
plt.figure(figsize=(10,7))
plt.title('Age Distribution of Data')
sns.countplot(data.Age)
plt.show()

# %% [markdown]
# ### Maximum number of people has age group 55

# %%
plt.figure(figsize=(10,7))
plt.title('Age Distribution of Data')
sns.histplot(data.Age)
plt.show()

# %%
print('The max Salary:',data.Age.max())
print('The min Salary:',data.Age.min())
# Out:
# The max Salary: 60
# The min Salary: 18

# %% [markdown]
# ### From the above charts , it is clear that there all the ages are more or less equally distruibuted across the data set.

# %%
plt.figure(figsize=(10, 8))
plt.title("Salary distribution in dataset", size=20)
plt.xlabel('Salary Range')
sns.histplot(data['Salary'])
# Out:
# <AxesSubplot:title={'center':'Salary distribution in dataset'}, xlabel='Salary Range', ylabel='Count'>

# %%
print('The max Salary:',data.Salary.max())
print('The min Salary:',data.Salary.min())
# Out:
# The max Salary: 10000
# The min Salary: 520

# %% [markdown]
# ### It is a completely good dataset all the data's are almost equally distributed. From the above charts , it is clear that there all the ages are more or less equally distruibuted across the dataset.

# %%
plt.figure(figsize=(20,8))
plt.suptitle("Salary diffrence in Male and Female", size=20)
sns.histplot(x='Salary',hue='Gender',data=data,multiple='dodge')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Count'>

# %% [markdown]
# ### From the above charts , it is clear that , almost equal distribution are occur, but some salary male narrow hike and some point female has narrow hike

# %%
plt.figure(figsize=(10,8))
df.groupby('Gender')['Salary'].mean().plot(kind='bar')
plt.title("Avg Salary Diffrence between Genders ")
plt.show()

# %% [markdown]
# ### From the above charts Males are slightly more as compair to female

# %%
plt.figure(figsize=(20,8))
data.groupby('Occupation')['Salary'].mean().plot(kind='bar')
plt.title("Avg Salary of Diffrence between Occupations ")
plt.show()

# %%
M =data[data['Gender']=='Male']
F =data[data['Gender']=='Female']

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Gender',hue='MaritalStatus',data=M)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### From the dataset  Unmarried male is more as compair to married male

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Gender',hue='MaritalStatus',data=F)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# ### From the dataset Unmarried female is little bit more as compair to married female

# %%
labels = ['2', '1', '0', '5', '4', '3']
Values = data['No.ofChildren'].value_counts().values

# %%
fig1,ax1 = plt.subplots()
ax1.pie(Values,labels=labels,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### In given data 16.6%,17%,18%,15.7%,16.2%,16.5% of people have 0,1,2,3,4,5 childs respectively

# %%
plt.figure(figsize=(10,10))
data.Age.value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# ### 3.5% of people has age group 55 which is maximum

# %%
labels = ['Male','Female']
Values = data['Gender'].value_counts().values

# %%
fig1,ax1 = plt.subplots()
colors = ['gold','lightskyblue']
ax1.pie(Values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %% [markdown]
# ### 51.4% are males and 48.6% are females

# %%
plt.figure(figsize=(15,15))
data.Occupation.value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Occupation'>

# %% [markdown]
# ### As compare to other occupation highest persentage of people are work as Insurer in given data i.e.,2.9%  while lowest number of people are scientist i.e.,0.9%

# %%
labels = ['Married','Unmarried']
Values = data['MaritalStatus'].value_counts().values
fig1,ax1 = plt.subplots()
colors = ['gold','lightskyblue']
ax1.pie(Values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %% [markdown]
# ### 51.3% are married and 48.7% are unmarried

# %%
plt.figure(figsize=(12, 8))
plt.suptitle("Top most popular job among Male", size=20)
data[data.Gender=='Male'].Occupation.value_counts().iloc[0:11].plot(kind='bar')
plt.xlabel('Occupation Title')
# Out:
# Text(0.5, 0, 'Occupation Title')

# %% [markdown]
# ### Insure are the most popular job amoung males

# %%
plt.figure(figsize=(12, 8))
plt.suptitle("Top most popular job among Female", size=20)
data[data.Gender=='Female'].Occupation.value_counts().iloc[0:11].plot(kind='bar')
plt.xlabel('Occupation Title')
# Out:
# Text(0.5, 0, 'Occupation Title')

# %% [markdown]
# ### Social worker and Lawer are top most popular jobs among Female.

# %%
plt.figure(figsize=(15, 8))
plt.suptitle("Top 10 avg high paying Occupation in dataset", size=10)
data.groupby('Occupation').mean().sort_values('Salary',ascending=False).head(10)['Salary'].plot(kind='bar')
plt.xlabel('Occupation')
# Out:
# Text(0.5, 0, 'Occupation')

# %% [markdown]
# ### This graph showing Top 10 avg highest paying Occupation in dataset.

# %%
plt.figure(figsize=(15, 8))
plt.suptitle("Top 10 avg low paying Occupation in dataset", size=10)
data.groupby('Occupation').mean().sort_values('Salary',ascending=True).head(10)['Salary'].plot(kind='bar')
plt.xlabel('Occupation')
# Out:
# Text(0.5, 0, 'Occupation')

# %% [markdown]
# ### This graph showing Top 10 avg low paying Occupation in dataset.
